# %%
import anndata as ad

# %%
dummy_adr = ad.read_h5ad("writing_back/adr_written_complete.h5ad")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 dummy_adr = ad.read_h5ad("writing_back/adr_written_complete.h5ad")
#
# File ~/Work/anndataR_benchmark/.venv/lib/python3.12/site-packages/anndata/_io/h5ad.py:285, in read_h5ad(filename, backed, as_sparse, as_sparse_fmt, chunk_size)
#     282         return read_dataframe(elem)
#     283     return read_func(elem)
# --> 285 adata = read_dispatched(f, callback=callback)
#     287 # Backwards compat (should figure out which version)
#     288 if "raw.X" in f:
#
# File ~/Work/anndataR_benchmark/.venv/lib/python3.12/site-packages/anndata/experimental/_dispatch_io.py:39, in read_dispatched(elem, callback)
#      35 from anndata._io.specs import _REGISTRY, Reader
#      37 reader = Reader(_REGISTRY, callback=callback)
# ---> 39 return reader.read_elem(elem)
#
# ...

# %%
adr_obs = ad.read_h5ad("writing_back/adr_written_obs.h5ad")
adr_var = ad.read_h5ad("writing_back/adr_written_var.h5ad")
adr_layers = ad.read_h5ad("writing_back/adr_written_layers.h5ad")
# adr_obsm = ad.read_h5ad("writing_back/adr_written_obsm.h5ad")
# adr_varm = ad.read_h5ad("writing_back/adr_written_varm.h5ad")
adr_obsp = ad.read_h5ad("writing_back/adr_written_obsp.h5ad")
adr_varp = ad.read_h5ad("writing_back/adr_written_varp.h5ad")
adr_uns = ad.read_h5ad("writing_back/adr_written_uns.h5ad")

# %%
adr_obsm = ad.read_h5ad("writing_back/adr_written_obsm.h5ad")
adr_varm = ad.read_h5ad("writing_back/adr_written_varm.h5ad")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 adr_obsm = ad.read_h5ad("writing_back/adr_written_obsm.h5ad")
#       2 adr_varm = ad.read_h5ad("writing_back/adr_written_varm.h5ad")
#
# File ~/Work/anndataR_benchmark/.venv/lib/python3.12/site-packages/anndata/_io/h5ad.py:285, in read_h5ad(filename, backed, as_sparse, as_sparse_fmt, chunk_size)
#     282         return read_dataframe(elem)
#     283     return read_func(elem)
# --> 285 adata = read_dispatched(f, callback=callback)
#     287 # Backwards compat (should figure out which version)
#     288 if "raw.X" in f:
#
# File ~/Work/anndataR_benchmark/.venv/lib/python3.12/site-packages/anndata/experimental/_dispatch_io.py:39, in read_dispatched(elem, callback)
#      35 from anndata._io.specs import _REGISTRY, Reader
#      37 reader = Reader(_REGISTRY, callback=callback)
# ...

# %%
adr_nodf = ad.read_h5ad("writing_back/adr_written_no_df.h5ad")

# %%
adr_nodf.uns.keys()
# Out:
# dict_keys(['bool_matrix', 'bool_matrix_3d', 'boolean', 'boolean_array', 'categorical', 'categorical_missing_values', 'categorical_ordered', 'categorical_ordered_missing_values', 'char', 'dataframe', 'dense_array', 'float', 'float_csparse', 'float_csparse_nas', 'float_matrix', 'float_matrix_3d', 'float_matrix_nas', 'float_rsparse', 'float_rsparse_nas', 'integer', 'integer_array', 'integer_csparse', 'integer_matrix', 'integer_matrix_3d', 'integer_rsparse', 'nan', 'nested', 'none', 'nullable_boolean_array', 'nullable_integer_array', 'string', 'string_array', 'string_matrix', 'string_matrix_3d'])

# %%
adr_nodf.uns["none"]

# %% [markdown]
# ANNDATAR | writing | obsm | dataframe | FAIL
#
# ANNDATAR | writing | varm | dataframe | FAIL
#
# ANNDATAR | writing | uns  | none      | FAIL
#
# ANNDATAR | writing | rest | OK
